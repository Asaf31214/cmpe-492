# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# %%
SPAs = [2.72, 2.47, 1.50, 1.56, 2.40, 0.29, 1.53, 0.00, 2.45, 1.75, 4.00, 3.25, 3.73]
GPAs = [2.72, 2.60, 2.21, 2.15, 2.17, 1.81, 1.91, 1.91, 2.43, 2.32, 2.35, 2.43, 2.55]
terms = ["2021/2022-1", "2021/2022-2", "2022/2023-1", "2022/2023-2", "2022/2023-3", "2023/2024-1", "2023/2024-2", "2023/2024-3", "2024/2025-1", "2024/2025-2", "2024/2025-3", "2025/2026-1", "2025/2026-2"]

# %%
plt.figure(figsize=(12, 9))

plt.plot(terms, GPAs, label='GPA')
plt.plot(terms, SPAs, label='SPA')
plt.xticks(rotation=75)
plt.legend()

plt.gca().yaxis.set_major_locator(MultipleLocator(0.1))
plt.grid(axis='y')
plt.ylim(0, 4)
plt.show()
